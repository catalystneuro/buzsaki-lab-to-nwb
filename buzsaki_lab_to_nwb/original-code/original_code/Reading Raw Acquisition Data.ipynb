# %%
import numpy as np
import neuroscope as ns
from bs4 import BeautifulSoup

# %%
with open('D:/BuzsakiData/SenzaiY/YutaMouse41/YutaMouse41-150903/YutaMouse41-150903.xml', 'r') as xml_file:
    contents = xml_file.read()
    soup = BeautifulSoup(contents, 'xml')

# %%
soup
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <parameters creator="ndManager-" version="1.0">
# <generalInfo>
# <date>2015-08-31</date>
# <experimenters>yuta</experimenters>
# <description/>
# <notes/>
# </generalInfo>
# <acquisitionSystem>
# <nBits>16</nBits>
# <nChannels>80</nChannels>
# <samplingRate>20000</samplingRate>
# <voltageRange>20</voltageRange>
# <amplification>1000</amplification>
# <offset>0</offset>
# </acquisitionSystem>
# <fieldPotentials>
# <lfpSamplingRate>1250</lfpSamplingRate>
# </fieldPotentials>
# <anatomicalDescription>
# <channelGroups>
# <group>
# <channel skip="0">33</channel>
# <channel skip="0">38</channel>
# <channel skip="0">32</channel>
# <channel skip="0">39</channel>
# <channel skip="0">35</channel>
# <channel skip="0">36</channel>
# <channel skip="0">34</channel>
# <channel skip="0">37</channel>
# </group>
# <group>
# <channel skip="0">41</channel>
# <channel skip="0">46</channel>
# <channel skip="0">40</channel>
# <channel skip="0">47</channel>
# ...

# %%
nChannels = int(soup.nChannels.string)
nSamples = int(soup.nSamples.string)
bitType = int(soup.nBits.string)

# %%
print(nChannels)
print(nSamples)
print(bitType)
# Out:
# 80
# 32
# 16

# %%
filename = 'D:/BuzsakiData/SenzaiY/YutaMouse41/YutaMouse41-150903/YutaMouse41-150903.dat'
f = np.memmap(filename, dtype='int16', mode='r', shape=(int(6459056000/80),80))

# %%
f[0:20,0]
# Out:
# memmap([2672, 2696, 2684, 2652, 2608, 2612, 2624, 2580, 2544, 2580, 2560,
#         2592, 2596, 2524, 2532, 2544, 2552, 2564, 2596, 2640], dtype=int16)

# %%
import os
dat_filesize = os.path.getsize('D:/BuzsakiData/SenzaiY/YutaMouse41/YutaMouse41-150903/YutaMouse41-150903.dat')
nItems = int(dat_filesize/np.int16(0).nbytes)
print(nItems)
# Out:
# 64590560000

# %%
import spikeinterface.extractors as se

nre = se.NeuroscopeRecordingExtractor('D:/BuzsakiData/SenzaiY/YutaMouse41/YutaMouse41-150903')

# %%
nre

# %%
nre.get_traces().shape
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-11-5b50caad8fe5> in <module>
# ----> 1 nre.get_traces().shape
#
# d:\github\spikeextractors\spikeextractors\extraction_tools.py in corrected_args(*args, **kwargs)
#     758
#     759         # pass recording as arg and rest as kwargs
# --> 760         get_traces_correct_arg = func(args[0], **kwargs)
#     761
#     762         return get_traces_correct_arg
#
# d:\github\spikeextractors\spikeextractors\extractors\neuroscopeextractors\neuroscopeextractors.py in get_traces(self, channel_ids, start_frame, end_frame)
#      71     @check_get_traces_args
#      72     def get_traces(self, channel_ids=None, start_frame=None, end_frame=None):
# ---> 73         return self._recording[start_frame:end_frame,channel_ids]
#      74
#      75     @staticmethod
#
# ...

# %%
nre.get_traces(0,0,10)
# Out:
# array([[2672],
#        [2696],
#        [2684],
#        [2652],
#        [2608],
#        [2612],
#        [2624],
#        [2580],
#        [2544],
#        [2580]], dtype=int16)
