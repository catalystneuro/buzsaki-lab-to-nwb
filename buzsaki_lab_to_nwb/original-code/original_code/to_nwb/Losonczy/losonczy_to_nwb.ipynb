# %%
from pynwb import NWBFile, NWBHDF5IO

# %%
# %matplotlib inline
from pickle import load
import matplotlib.pyplot as plt
import numpy as np
from lfp_helpers import loadEEG

# %%
aa = loadEEG('/Users/bendichter/Desktop/Losonczy/from_sebi/example_data/LFP/svr009_Day2_FOV1_170504_131823')

# %%
aa
# Out:
# {'EEG': array([[  93,   79,   62, ...,  -89,  -51,  -76],
#         [ 184,  145,   78, ...,   32,   43,   28],
#         [  -3,   -2,   -3, ...,    0,   -2,   -1],
#         [-296, -299, -319, ..., -570, -514, -550],
#         [-112, -138, -195, ..., -459, -408, -438],
#         [   1,  171,    2, ...,    2,    2,    3]], dtype=int16),
#  'channels': [0, 1, 2, 3, 4, 5],
#  'fileBase': '/Users/bendichter/Desktop/Losonczy/from_sebi/example_data/LFP/svr009_Day2_FOV1_170504_131823',
#  'filePath': '/Users/bendichter/dev/to_nwb/Losonczy',
#  'nChannels': 6,
#  'sampeFreq': 1250.0,
#  'tEEG': array([  0.00000000e+00,   8.00000000e-04,   1.60000000e-03, ...,
#           1.20840480e+03,   1.20840560e+03,   1.20840640e+03])}

# %%
with open('/Users/bendichter/Desktop/Losonczy/from_sebi/example_data/svr009_20170504131836.pkl','rb') as f:
    aa = load(f)

# %%
aa.keys()
# Out:
# ['recordingDuration',
#  'trackLength',
#  'licking',
#  'water',
#  'treadmillPosition',
#  'position_y',
#  'reward',
#  'lap']

# %%
aa['trackLength']
# Out:
# array(2050.0)

# %%
plt.plot(aa['position_y'][:,0])
plt.plot(aa['treadmillPosition'][:,0])

# %%
plt.plot(aa['water'][:,0],'.')

# %%
plt.plot(aa['treadmillPosition'][:,1])

# %%
plt.plot(aa['licking'][:,0], aa['licking'][:,1])

# %%
# Out:
# (3505,)
